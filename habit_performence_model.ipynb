# %% [markdown]
# <i>Imorting files</i>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('student_habits_performance.csv')
display(df.head())
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df = df.drop('student_id', axis=1)
display(df)
# Out:
#      age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0     23  Female                  0.0                 1.2            1.1
# 1     20  Female                  6.9                 2.8            2.3
# 2     21    Male                  1.4                 3.1            1.3
# 3     23  Female                  1.0                 3.9            1.0
# 4     19  Female                  5.0                 4.4            0.5
# ..   ...     ...                  ...                 ...            ...
# 995   21  Female                  2.6                 0.5            1.6
# 996   17  Female                  2.9                 1.0            2.4
# 997   20    Male                  3.0                 2.6            1.3
# 998   24    Male                  5.4                 4.1            1.1
# 999   19  Female                  4.3                 2.9            1.9
#
#     part_time_job  attendance_percentage  sleep_hours diet_quality  \
# ...

# %%
cat = df.select_dtypes(include='object').columns
for i in cat:
  df = df.dropna(subset=[i])

# %%
for col in df.columns:
  print(f"Unique values in '{col}':")
  display(df[col].unique())
  print("-" * 30)
# Out:
# Unique values in 'age':
# array([23, 20, 21, 19, 24, 18, 22, 17])
# ------------------------------
# Unique values in 'gender':
# array(['Female', 'Male', 'Other'], dtype=object)
# ------------------------------
# Unique values in 'study_hours_per_day':
# array([0. , 6.9, 1.4, 1. , 5. , 7.2, 5.6, 4.3, 4.4, 4.8, 3.9, 3.7, 3.4,
#        2.4, 3.1, 2. , 1.8, 3.8, 4.9, 1.1, 3.2, 1.5, 2.6, 4.2, 3.5, 5.5,
#        2.9, 3.6, 6.1, 1.6, 2.5, 5.4, 2.2, 6.7, 1.7, 4. , 4.5, 4.1, 3.3,
#        6.8, 2.7, 7.4, 6. , 5.9, 2.3, 1.2, 0.5, 5.3, 2.1, 5.1, 1.9, 3. ,
#        4.6, 0.7, 0.3, 4.7, 5.8, 5.7, 1.3, 0.8, 2.8, 6.2, 6.5, 0.6, 6.6,
#        0.9, 6.3, 5.2, 8.3, 6.4, 0.2, 7.5, 8.2, 7.6, 0.1, 7.1])
# ------------------------------
# Unique values in 'social_media_hours':
# array([1.2, 2.8, 3.1, 3.9, 4.4, 1.3, 1.5, 1. , 2.2, 2.4, 2.1, 2.7, 5. ,
#        0.6, 4.9, 2.5, 2.3, 4.1, 0. , 4.3, 0.8, 2. , 3.2, 1.7, 3. , 4.7,
#        3.4, 0.9, 1.4, 3.6, 1.9, 4.2, 1.8, 0.3, 3.7, 0.1, 3.3, 2.6, 2.9,
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in cat:
  df[col] = le.fit_transform(df[col])

# %%
for col in df.columns:
  print(f"Unique values in '{col}':")
  display(df[col].unique())
  print("-" * 30)
# Out:
# Unique values in 'age':
# array([23, 20, 21, 19, 24, 18, 22, 17])
# ------------------------------
# Unique values in 'gender':
# array([0, 1, 2])
# ------------------------------
# Unique values in 'study_hours_per_day':
# array([0. , 6.9, 1.4, 1. , 5. , 7.2, 5.6, 4.3, 4.4, 4.8, 3.9, 3.7, 3.4,
#        2.4, 3.1, 2. , 1.8, 3.8, 4.9, 1.1, 3.2, 1.5, 2.6, 4.2, 3.5, 5.5,
#        2.9, 3.6, 6.1, 1.6, 2.5, 5.4, 2.2, 6.7, 1.7, 4. , 4.5, 4.1, 3.3,
#        6.8, 2.7, 7.4, 6. , 5.9, 2.3, 1.2, 0.5, 5.3, 2.1, 5.1, 1.9, 3. ,
#        4.6, 0.7, 0.3, 4.7, 5.8, 5.7, 1.3, 0.8, 2.8, 6.2, 6.5, 0.6, 6.6,
#        0.9, 6.3, 5.2, 8.3, 6.4, 0.2, 7.5, 8.2, 7.6, 0.1, 7.1])
# ------------------------------
# Unique values in 'social_media_hours':
# array([1.2, 2.8, 3.1, 3.9, 4.4, 1.3, 1.5, 1. , 2.2, 2.4, 2.1, 2.7, 5. ,
#        0.6, 4.9, 2.5, 2.3, 4.1, 0. , 4.3, 0.8, 2. , 3.2, 1.7, 3. , 4.7,
#        3.4, 0.9, 1.4, 3.6, 1.9, 4.2, 1.8, 0.3, 3.7, 0.1, 3.3, 2.6, 2.9,
# ...

# %% [markdown]
# *plots*

# %%
import matplotlib.pyplot as plt

# %%
for i in df.columns:
  plt.hist2d(df[i],df['exam_score'])
  plt.title(i)
  plt.show()

# %% [markdown]
# <i>Generating correlation matrix</i>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr_matrix = df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Student Habits and Performance')
plt.show()

# %%
# removing negative correlation columns with exam score
df = df.drop(['age','gender','social_media_hours','netflix_hours','part_time_job','diet_quality','parental_education_level','internet_quality'], axis=1)

# %%
display(df)
# Out:
#      study_hours_per_day  attendance_percentage  sleep_hours  \
# 0                    0.0                   85.0          8.0
# 1                    6.9                   97.3          4.6
# 2                    1.4                   94.8          8.0
# 3                    1.0                   71.0          9.2
# 4                    5.0                   90.9          4.9
# ..                   ...                    ...          ...
# 995                  2.6                   77.0          7.5
# 996                  2.9                   86.0          6.8
# 997                  3.0                   61.9          6.5
# 998                  5.4                  100.0          7.6
# 999                  4.3                   89.4          7.1
#
#      exercise_frequency  mental_health_rating  extracurricular_participation  \
# 0                     6                     8                              1
# ...

# %% [markdown]
# <i style="color: green">Creating Model</i>

# %%
from sklearn.model_selection import train_test_split

X = df.drop('exam_score', axis=1)
y = df['exam_score']
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# prompt: generate neural network model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(64, input_dim=x_train.shape[1], activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='linear')) # Output layer for regression

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
model.summary()
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 3642.4646 - mae: 56.7922 - val_loss: 1814.3668 - val_mae: 39.7775
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1292.8269 - mae: 30.8341 - val_loss: 269.5016 - val_mae: 13.3666
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 577.8065 - mae: 19.8187 - val_loss: 242.1911 - val_mae: 12.9004
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 582.2311 - mae: 19.4106 - val_loss: 271.6039 - val_mae: 13.3949
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 492.0984 - mae: 17.5828 - val_loss: 257.2525 - val_mae: 13.1518
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 516.9263 - mae: 18.1521 - val_loss: 244.6690 - val_mae: 12.9098
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 489.5595 - mae: 17.5845 - val_loss: 255.6090 - val_mae: 13.0574
# Epoch 8/100
# ...

# %%
y_pred = model.predict(x_test)
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 45.48823404922742
# R-squared: 0.8380612272790002

# %%
display(y_pred)
# Out:
# array([[ 62.55557 ],
#        [ 52.254868],
#        [ 72.74293 ],
#        [ 74.57694 ],
#        [ 84.229515],
#        [ 65.24468 ],
#        [ 81.02344 ],
#        [ 88.73624 ],
#        [ 61.616943],
#        [ 74.359795],
#        [ 57.15973 ],
#        [ 77.48688 ],
#        [ 52.35953 ],
#        [ 53.7003  ],
#        [ 79.82965 ],
#        [ 75.406685],
#        [ 48.98931 ],
#        [ 84.63083 ],
#        [ 82.28039 ],
#        [ 71.62916 ],
#        [ 75.33397 ],
#        [ 90.54337 ],
#        [ 46.252975],
#        [ 62.568394],
#        [ 83.06365 ],
#        [ 60.22198 ],
#        [ 99.819214],
#        [ 78.254395],
#        [ 64.90345 ],
#        [ 90.216286],
#        [ 59.693855],
#        [ 78.89959 ],
#        [ 55.67247 ],
#        [ 66.562355],
#        [ 62.838505],
#        [ 64.162766],
#        [ 90.79722 ],
#        [ 46.407288],
#        [ 63.804306],
#        [ 81.79269 ],
#        [ 65.74392 ],
#        [ 81.79866 ],
#        [ 71.450714],
# ...
